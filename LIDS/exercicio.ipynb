# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import math 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Use_Of_Force.csv')
df
# Out:
#                             ID  Incident_Num           Incident_Type
# 0        2014UOF-0001-1377-203           251  Level 1 - Use of Force  \
# 1        2014UOF-0002-1098-166           218  Level 1 - Use of Force
# 2        2014UOF-0003-1031-125           178  Level 1 - Use of Force
# 3         2014UOF-0004-767-126           179  Level 1 - Use of Force
# 4        2014UOF-0005-1473-172           223  Level 1 - Use of Force
# ...                        ...           ...                     ...
# 14259  2022UOF-0385-1274-28426         68121  Level 1 - Use of Force
# 14260  2022UOF-0386-3002-28426         68120  Level 1 - Use of Force
# 14261  2022UOF-0387-2614-15793         68032  Level 1 - Use of Force
# 14262  2022UOF-0388-2670-15793         68029  Level 1 - Use of Force
# 14263   2022UOF-0389-2739-8294         67659  Level 1 - Use of Force
#
#             Occured_date_time Precinct   Sector Beat  Officer_ID  Subject_ID
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Incident_Num', 'Incident_Type', 'Occured_date_time', 'Precinct',
#        'Sector', 'Beat', 'Officer_ID', 'Subject_ID', 'Subject_Race',
#        'Subject_Gender'],
#       dtype='object')

# %%
df ['Occured_date_time'] = pd.to_datetime(df['Occured_date_time'],format='%m/%d/%Y %I:%M:%S %p')
df
# Out:
#                             ID  Incident_Num           Incident_Type
# 0        2014UOF-0001-1377-203           251  Level 1 - Use of Force  \
# 1        2014UOF-0002-1098-166           218  Level 1 - Use of Force
# 2        2014UOF-0003-1031-125           178  Level 1 - Use of Force
# 3         2014UOF-0004-767-126           179  Level 1 - Use of Force
# 4        2014UOF-0005-1473-172           223  Level 1 - Use of Force
# ...                        ...           ...                     ...
# 14259  2022UOF-0385-1274-28426         68121  Level 1 - Use of Force
# 14260  2022UOF-0386-3002-28426         68120  Level 1 - Use of Force
# 14261  2022UOF-0387-2614-15793         68032  Level 1 - Use of Force
# 14262  2022UOF-0388-2670-15793         68029  Level 1 - Use of Force
# 14263   2022UOF-0389-2739-8294         67659  Level 1 - Use of Force
#
#         Occured_date_time Precinct   Sector Beat  Officer_ID  Subject_ID
# ...

# %%
df2 = df.sort_values('Occured_date_time',ascending = True,ignore_index=True)
df2
# Out:
#                             ID  Incident_Num           Incident_Type
# 0       2015UOF-0308-1259-3126          3552  Level 2 - Use of Force  \
# 1       2015UOF-0302-1134-3533          4121  Level 1 - Use of Force
# 2       2014UOF-1077-1819-1823          2042  Level 2 - Use of Force
# 3        2014UOF-1078-892-1823          2043  Level 2 - Use of Force
# 4       2014UOF-1079-1805-1823          2044  Level 2 - Use of Force
# ...                        ...           ...                     ...
# 14259  2022UOF-0334-1078-28403         68073  Level 1 - Use of Force
# 14260  2022UOF-0375-1464-28424         68117           Level 3 - OIS
# 14261  2022UOF-0384-3009-28426         68122  Level 1 - Use of Force
# 14262  2022UOF-0385-1274-28426         68121  Level 1 - Use of Force
# 14263  2022UOF-0386-3002-28426         68120  Level 1 - Use of Force
#
#         Occured_date_time Precinct  Sector Beat  Officer_ID  Subject_ID
# ...

# %%
# OCORRE ERRO (CORRIGIR)
df2['Occured_date_time'] = df2['Occured_date_time'].dt.round(freq='Y')

# %%
df2.drop_duplicates(subset=('Occured_date_time','Subject_ID'), keep='first', ignore_index=True,inplace=True)
df2
# Out:
#                             ID  Incident_Num           Incident_Type
# 0       2015UOF-0308-1259-3126          3552  Level 2 - Use of Force  \
# 1       2015UOF-0302-1134-3533          4121  Level 1 - Use of Force
# 2       2014UOF-1077-1819-1823          2042  Level 2 - Use of Force
# 3       2014UOF-1115-1235-1835          2048  Level 2 - Use of Force
# 4       2014UOF-0446-1399-1299          1329  Level 1 - Use of Force
# ...                        ...           ...                     ...
# 12055  2022UOF-0335-2203-28394         68061  Level 1 - Use of Force
# 12056  2022UOF-0334-1078-28403         68073  Level 1 - Use of Force
# 12057  2022UOF-0375-1464-28424         68117           Level 3 - OIS
# 12058  2022UOF-0384-3009-28426         68122  Level 1 - Use of Force
# 12059  2022UOF-0386-3002-28426         68120  Level 1 - Use of Force
#
#         Occured_date_time Precinct  Sector Beat  Officer_ID  Subject_ID
# ...

# %%
agr_year = df2.groupby(df2['Occured_date_time'].dt.year, sort=False)['Incident_Num'].count()
agr_year
# Out:
# Occured_date_time
# 2014    1202
# 2015    1735
# 2016    1399
# 2017    1446
# 2018    2016
# 2019    1170
# 2020    1825
# 2021     949
# 2022     318
# Name: Incident_Num, dtype: int64

# %%
plt.title('Crimes por Ano', size = 20)
agr_year.plot.bar()
# Out:
# <Axes: title={'center': 'Crimes por Ano'}, xlabel='Occured_date_time'>

# %%
agr_month = df2.groupby(df2['Occured_date_time'].dt.month, sort=False)['Incident_Num'].count()
agr_month

# %%
# proxima aula é aprendizado baysiano (naive bayes)
# terminar o conteúdo em predição
