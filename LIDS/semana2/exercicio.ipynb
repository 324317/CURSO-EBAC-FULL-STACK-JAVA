# %%
import pandas as pd
import numpy as np

netflix = pd.read_csv(r'/home/edgar/GIT/LIDS/semana2/netflix1.csv', sep = ',')
netflix
# Out:
#      show_id     type                             title         director
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration
# ...

# %%
netflix.head()
# Out:
#   show_id     type                             title         director
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration
# 0  United States  9/25/2021          2020  PG-13    90 min  \
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
# apenas uma coluna numérica
netflix.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
menor = netflix['release_year'].min()
maior = netflix['release_year'].max()

# %%
print(f'coluna "release_year": min = {menor} e max = {maior}')
# Out:
# coluna "release_year": min = 1925 e max = 2021

# %%
# filmes mais novos e os mais velhos 

netflix[netflix['release_year']==1925]
# Out:
#     show_id     type                              title   director   country
# 421   s4251  TV Show  Pioneers: First Women Filmmakers*  Not Given  Pakistan  \
#
#      date_added  release_year rating  duration listed_in
# 421  12/30/2018          1925  TV-14  1 Season  TV Shows

# %%
netflix[netflix['release_year']==2021]
# Out:
#      show_id     type                             title         director
# 1         s3  TV Show                         Ganglands  Julien Leclercq  \
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 5         s9  TV Show     The Great British Baking Show  Andy Devonshire
# 6        s10    Movie                      The Starling   Theodore Melfi
# ...      ...      ...                               ...              ...
# 6920   s1461  TV Show                           Monarca        Not Given
# 6922   s1467    Movie      The Minimalists: Less Is Now        Not Given
# 6948   s1552  TV Show                             Hilda        Not Given
# 6992   s1697  TV Show                      Polly Pocket        Not Given
# 7355   s2921  TV Show                     Love Is Blind        Not Given
#
#              country  date_added  release_year rating   duration
# ...

# %%
x = netflix.groupby(['director'])
x
